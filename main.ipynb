# %%
from k_means import * 
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
#%matplotlib inline
import seaborn as sns
sns.set(rc={'figure.figsize':(20,20)})

# %%
#creating training sample
##all samples must be in float 
training_sample = pd.DataFrame(data = {'x' : [random.uniform(0, 1) for _ in range(100)],
                                        'y' : [random.uniform(1, 5) for _ in range(100)]})


#create KMeans object
##it is recommended to have plot_every = 1 so that we could see the progress for each iteration 
max_iters = 3
k_means_obj = KMeans(n_clusters=4, 
                     max_iter=max_iters, plot_every = 1)

# %%
#train the KMeans object
clusters, centroids = k_means_obj.fit(training_sample)
# Out:
# training iteration: 1
# Plotting current clusters and centroid(s) position
# training iteration: 2
# Plotting current clusters and centroid(s) position
# training iteration: 3
# Plotting current clusters and centroid(s) position
# finished training...

# %%
#print the results of clusters and centroids
print('The clusters for each of the samples')
print(clusters)
print('---------------------------------')
print('The final position of centroids')
print(centroids)
# Out:
# The clusters for each of the samples
# [1, 2, 3, 0, 2, 2, 0, 1, 0, 2, 1, 2, 2, 0, 1, 1, 2, 2, 3, 0, 1, 2, 0, 2, 0, 2, 0, 0, 3, 2, 1, 2, 0, 2, 2, 0, 2, 3, 0, 0, 0, 0, 2, 0, 0, 1, 2, 0, 1, 3, 2, 3, 2, 0, 1, 3, 1, 3, 2, 0, 1, 2, 0, 1, 2, 1, 0, 3, 0, 0, 2, 1, 2, 0, 3, 0, 2, 2, 0, 2, 2, 3, 2, 2, 0, 0, 2, 1, 0, 0, 0, 2, 0, 2, 0, 0, 2, 3, 2, 0]
# ---------------------------------
# The final position of centroids
#           x         y
# 0  0.502529  2.961089
# 1  0.366572  4.063321
# 2  0.529990  1.762963
# 3  0.759431  4.616096

# %%
#predict new samples
new_sample = pd.DataFrame(data = {'x' : [random.uniform(0, 1) for _ in range(10)],
                                  'y' : [random.uniform(1, 5) for _ in range(10)]})

predicted_clusters = k_means_obj.predict(new_sample)
print('The clusters for new predict samples')
print(predicted_clusters)
# Out:
# The clusters for new predict samples
# [1, 2, 3, 0, 2, 2, 0, 1, 0, 2, 1, 2, 2, 0, 1, 1, 2, 2, 3, 0, 1, 2, 0, 2, 0, 2, 0, 0, 3, 2, 1, 2, 0, 2, 2, 0, 2, 3, 0, 0, 0, 0, 2, 0, 0, 1, 2, 0, 1, 3, 2, 3, 2, 0, 1, 3, 1, 3, 2, 0, 1, 2, 0, 1, 2, 1, 0, 3, 0, 0, 2, 1, 2, 0, 3, 0, 2, 2, 0, 2, 2, 3, 2, 2, 0, 0, 2, 1, 0, 0, 0, 2, 0, 2, 0, 0, 2, 3, 2, 0]

# %%
#plotting method
k_means_obj.plot()
# Out:
# Plotting current clusters and centroid(s) position
